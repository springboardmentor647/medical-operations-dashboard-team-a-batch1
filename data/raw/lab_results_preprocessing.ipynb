# %%
lab.to_csv("lab_results_clean.csv", index=False)

print("Saved cleaned file as lab_results_clean.csv")
print("Final shape:", lab.shape)
# Out:
# Saved cleaned file as lab_results_clean.csv
# Final shape: (5000, 4)

# %%
invalid_values = lab[lab["Value"] < 0]
print("Negative Value rows:", len(invalid_values))
# Out:
# Negative Value rows: 0

# %%
lab.dtypes
# Out:
# Lab_ID           object
# Admission_ID     object
# Test             object
# Value           float64
# dtype: object

# %%
text_columns = ["Lab_ID", "Admission_ID", "Test"]

for col in text_columns:
    lab[col] = lab[col].str.strip()

# %%
print("Duplicate Lab_IDs:", lab["Lab_ID"].duplicated().sum())
# Out:
# Duplicate Lab_IDs: 0

# %%
print("Missing values per column:")
lab.isnull().sum()
# Out:
# Missing values per column:
# Lab_ID          0
# Admission_ID    0
# Test            0
# Value           0
# dtype: int64

# %%
print(lab.columns)
# Out:
# Index(['Lab_ID', 'Admission_ID', 'Test', 'Value'], dtype='object')

# %%
print("Full duplicate rows:", lab.duplicated().sum())
# Out:
# Full duplicate rows: 0

# %%
lab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Lab_ID        5000 non-null   object
#  1   Admission_ID  5000 non-null   object
#  2   Test          5000 non-null   object
#  3   Value         5000 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 156.4+ KB

# %%
import pandas as pd

lab = pd.read_csv("lab_results.csv")
print("Initial shape:", lab.shape)
lab.head()
# Out:
# Initial shape: (5000, 4)
#    Lab_ID Admission_ID         Test   Value
# 0  L00001       A00001  Blood Sugar   91.27
# 1  L00002       A00002  Blood Sugar  175.69
# 2  L00003       A00003  Cholesterol  150.60
# 3  L00004       A00004  Cholesterol  176.53
# 4  L00005       A00005  Blood Sugar  133.46
